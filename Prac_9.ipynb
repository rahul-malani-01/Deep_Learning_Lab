# %%
# Rahul Malani - 23070521088
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Example vocabulary
vocab_size = 1000
num_slots = 10
max_length = 20

# Example training data
X_train = np.random.randint(
    1, vocab_size,
    size=(1000, max_length)
)

y_train = np.random.randint(
    0, num_slots,
    size=(1000, max_length)
)

# Build model
model = Sequential([
    Embedding(
        input_dim=vocab_size,
        output_dim=64,
        input_length=max_length
    ),

    LSTM(
        64,
        return_sequences=True
    ),

    Dense(
        num_slots,
        activation="softmax"
    )
])

# Compile
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# Train
history = model.fit(
    X_train,
    y_train,
    epochs=30,
    batch_size=32,
    validation_split=0.2
)

# Evaluate
loss, accuracy = model.evaluate(X_train, y_train)

print("Accuracy:", accuracy)
# Out:
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.0978 - loss: 2.3027 - val_accuracy: 0.0995 - val_loss: 2.3029
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1348 - loss: 2.2987 - val_accuracy: 0.0970 - val_loss: 2.3030
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1632 - loss: 2.2907 - val_accuracy: 0.0963 - val_loss: 2.3043
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1767 - loss: 2.2679 - val_accuracy: 0.1022 - val_loss: 2.3123
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1911 - loss: 2.2301 - val_accuracy: 0.1010 - val_loss: 2.3335
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2066 - loss: 2.1901 - val_accuracy: 0.1025 - val_loss: 2.3547
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2208 - loss: 2.1532 - val_accuracy: 0.1018 - val_loss: 2.3929
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.2328 - loss: 2.1200 - val_accuracy: 0.1042 - val_loss: 2.4349
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2433 - loss: 2.0904 - val_accuracy: 0.1055 - val_loss: 2.4603
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2528 - loss: 2.0652 - val_accuracy: 0.1005 - val_loss: 2.5024
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2605 - loss: 2.0409 - val_accuracy: 0.1042 - val_loss: 2.5436
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2709 - loss: 2.0158 - val_accuracy: 0.1030 - val_loss: 2.5917
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2788 - loss: 1.9927 - val_accuracy: 0.1010 - val_loss: 2.6195
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2854 - loss: 1.9726 - val_accuracy: 0.1048 - val_loss: 2.6728
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2919 - loss: 1.9503 - val_accuracy: 0.1023 - val_loss: 2.6987
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.2991 - loss: 1.9302 - val_accuracy: 0.1037 - val_loss: 2.7778
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3031 - loss: 1.9100 - val_accuracy: 0.1037 - val_loss: 2.7932
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.3134 - loss: 1.8928 - val_accuracy: 0.1010 - val_loss: 2.8616
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3199 - loss: 1.8735 - val_accuracy: 0.0993 - val_loss: 2.8836
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3249 - loss: 1.8586 - val_accuracy: 0.1018 - val_loss: 2.8784
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.3262 - loss: 1.8452 - val_accuracy: 0.1025 - val_loss: 2.9592
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3343 - loss: 1.8256 - val_accuracy: 0.1048 - val_loss: 2.9744
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3384 - loss: 1.8109 - val_accuracy: 0.1035 - val_loss: 3.0180
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3446 - loss: 1.7972 - val_accuracy: 0.1082 - val_loss: 3.0635
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3543 - loss: 1.7752 - val_accuracy: 0.1050 - val_loss: 3.0942
# Epoch 26/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3573 - loss: 1.7592 - val_accuracy: 0.1120 - val_loss: 3.1660
# Epoch 27/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3611 - loss: 1.7481 - val_accuracy: 0.1088 - val_loss: 3.1987
# Epoch 28/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3642 - loss: 1.7349 - val_accuracy: 0.1112 - val_loss: 3.1918
# Epoch 29/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3668 - loss: 1.7218 - val_accuracy: 0.1088 - val_loss: 3.2394
# Epoch 30/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3757 - loss: 1.7052 - val_accuracy: 0.1115 - val_loss: 3.3108
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3286 - loss: 2.0047
# Accuracy: 0.3285500705242157
