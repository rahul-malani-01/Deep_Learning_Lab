# %% [markdown]
# **Rahul Malani - 23070521088**

# %%
# ------------------------------------------------
# 10.1. L1L2 Regularization Model
# ------------------------------------------------

l1l2_model = create_model(
    l1_strength=0.001,
    l2_strength=0.001,
    dropout=False
)

history_l1l2 = l1l2_model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    verbose=0
)

results.append(("L1L2",) + evaluate(
    l1l2_model,
    history_l1l2,
    "L1L2 Regularization"
))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ...
# L1L2 Regularization
# ...
# Training Loss : 25088548143104.0
# Validation Loss: 24532582662144.0
# Test MAE : 4984763.5
# Test MSE : 29821975396352.0
# Test RMSE : 5460950.05

# %%
# ------------------------------------------------
# 10.2. New Dense + Dropout Model
# ------------------------------------------------

new_dropout_model = create_model(
    l1_strength=0.0,
    l2_strength=0.0,
    dropout=True
)

history_new_dropout = new_dropout_model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    verbose=0
)

results.append(("New Dropout",) + evaluate(
    new_dropout_model,
    history_new_dropout,
    "New Dropout Model"
))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ...
# New Dropout Model
# ...
# Training Loss : 25103362424832.0
# Validation Loss: 24547145285632.0
# Test MAE : 4985998.5
# Test MSE : 29840619077632.0
# Test RMSE : 5462656.78

# %%
# ------------------------------------------------
# 10.3. New Dense (No Dropout) Model
# ------------------------------------------------

new_baseline_model = create_model(
    l1_strength=0.0,
    l2_strength=0.0,
    dropout=False
)

history_new_baseline = new_baseline_model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    verbose=0
)

results.append(("New Baseline",) + evaluate(
    new_baseline_model,
    history_new_baseline,
    "New Baseline Model"
))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ...
# New Baseline Model
# ...
# Training Loss : 24989375922176.0
# Validation Loss: 24442455457792.0
# Test MAE : 4976571.5
# Test MSE : 29706011279360.0
# Test RMSE : 5450322.13

# %%
print("\nUpdated Model Comparison with L1L2, New Dropout, and New Baseline Models")
print(comparison)
# Out:
# Updated Model Comparison with L1L2, New Dropout, and New Baseline Models
#       Model  Training Loss  Validation Loss   Test MAE      Test MSE  \
# 0  Baseline   2.506546e+13     2.451354e+13  4983550.0  2.979299e+13
# 1        L1   2.504806e+13     2.449227e+13  4981324.5  2.976917e+13
# 2        L2   2.508542e+13     2.452417e+13  4984230.0  2.981509e+13
# 3   Dropout   2.509079e+13     2.454061e+13  4985625.0  2.982761e+13
#
#       Test RMSE
# 0  5.458295e+06
# 1  5.456113e+06
# 2  5.460320e+06
# 3  5.461466e+06
