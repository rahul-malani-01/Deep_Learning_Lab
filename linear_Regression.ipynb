# %% [markdown]
# **Rahul Malani - 23070521088**

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
# Define the data
x = np.array([1, 2, 3, 4, 5])
y = np.array([20, 40, 50, 65, 80])

# Reshape x for scikit-learn's LinearRegression (needs a 2D array)
X = x.reshape(-1, 1)

# %%
# Create and fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions
y_pred = model.predict(X)

# %%
# Calculate the Mean Absolute Error
mae = mean_absolute_error(y, y_pred)

print(f"Original y values: {y}")
print(f"Predicted y values: {y_pred.round(2)}") # Round for cleaner display
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Original y values: [20 40 50 65 80]
# Predicted y values: [22.  36.5 51.  65.5 80. ]
# Mean Absolute Error (MAE): 1.40

# %%
import numpy as np
x = np.array([1, 2, 3, 4, 5])
y = np.array([20, 40, 50, 65, 80])
X = x.reshape(1, -1)

# %%
print(x)
# Out:
# [1 2 3 4 5]

# %%
x = np.array([100, 150, 200, 250, 300])
y = np.array([20, 25, 30, 35, 40])

X = x.reshape(-1, 1)

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

# %%
mae = mean_absolute_error(y, y_pred)

print(f"Original y values: {y}")
print(f"Predicted y values: {y_pred.round(2)}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
# Original y values: [20 25 30 35 40]
# Predicted y values: [20. 25. 30. 35. 40.]
# Mean Absolute Error (MAE): 0.00
